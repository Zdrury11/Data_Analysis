# %% [markdown]
# # East-West University
#
# # CI280 Final Exam - 2020 Fall  (100 points)
#
# # Student Name:
#
# # Student ID:

# %% [markdown]
# ### Real Estate Data  Analysis

# %%
# %matplotlib inline
import random
import pandas as pd
import matplotlib.pyplot as plt

plt.rc('figure', figsize=(12, 10))

# %%
# limiting the display rows
pd.set_option('display.max_rows', 10)

# %%
df = pd.read_csv("RealEstate.csv")
print(df.shape)
df
# Out:
# (81, 8)
#     Trans_No               Address            City Selling_Agent  \
# 0          1     8687 Kenwood Road     Cedar Hills     Hernandez
# 1          2    11 West Oak Circle   American Fork         Carey
# 2          3   314 Timp View Drive   American Fork      Goodrich
# 3          4  614 West Cedar Drive            Lehi          Lugo
# 4          5   750 South Apple Way   American Fork      Goodrich
# ..       ...                   ...             ...           ...
# 76        77          516 East Oak  Eagle Mountain        Pijuan
# 77        78        123 Oak Avenue   American Fork         Carey
# 78        79          600 Ivy Lane  Eagle Mountain        Pijuan
# 79        80        144 Oak Avenue   American Fork      Goodrich
# 80        81    1600 Reeves Street     Cedar Hills        Reuter
#
#     Asking_Price  Selling_Price Listing_Date  Sale_Date
# 0         725000         645250     4/1/2018  6/16/2018
# 1         350000         340000     4/1/2018  5/15/2018
# ...

# %% [markdown]
# # Part A: Basic Dataframe ( 50 pts)

# %%
import random

number = random.randint(0,10000)
print("Zach Drury , dr21637 ", number )
print('------------------------------')

# Problem 1 ( 3 = 3 = 6 pts)
# Display datafrome realEstate column names

names = df.columns
names

print("Display columns by each line")
print("------------------------------")
for name in names:
    print(name)
# Out:
# Zach Drury , dr21637  8139
# ------------------------------
# Display columns by each line
# ------------------------------
# Trans_No
# Address
# City
# Selling_Agent
# Asking_Price
# Selling_Price
# Listing_Date
# Sale_Date

# %%
number = random.randint(0,10000)
print("Zach Drury , dr21637 ", number )
print('------------------------------')

# Problem 2. (3 + 3 = 6 points)
# Diplay DataFrame realEstate's three columns:  rans_No , Selling_Agent, Asking_Price

names = df[['Trans_No','Selling_Agent','Asking_Price']]
names
# Out:
# Zach Drury , dr21637  2991
# ------------------------------
#     Trans_No Selling_Agent  Asking_Price
# 0          1     Hernandez        725000
# 1          2         Carey        350000
# 2          3      Goodrich        418000
# 3          4          Lugo        215800
# 4          5      Goodrich        385900
# ..       ...           ...           ...
# 76        77        Pijuan        299999
# 77        78         Carey        400000
# 78        79        Pijuan        339999
# 79        80      Goodrich        380500
# 80        81        Reuter        245900
#
# [81 rows x 3 columns]

# %%
number = random.randint(0,10000)
print("Zach Drury , dr21637 ", number )
print('------------------------------')
# Problem 3. ( 8 points)
# Show all realestates in the city of Cedar Hills or American Fork

names = df[df['City'] == 'Cedar Hills']
names
# Out:
# Zach Drury , dr21637  2758
# ------------------------------
#     Trans_No                   Address         City Selling_Agent  \
# 0          1         8687 Kenwood Road  Cedar Hills     Hernandez
# 31        32  9408 Forest Hills Circle  Cedar Hills        Reuter
# 33        34      11971 SW 269 Terrace  Cedar Hills         Carey
# 34        35           1857 Pine Drive  Cedar Hills     Hernandez
# 36        37    16235 Orange Boulevard  Cedar Hills          Lugo
# ..       ...                       ...          ...           ...
# 58        59           21 Compass Road  Cedar Hills        Merkin
# 67        68     4916 Rock Spring Road  Cedar Hills          Lugo
# 70        71       1132 SW 52nd Street  Cedar Hills     Hernandez
# 72        73           10 Vestal Drive  Cedar Hills         Carey
# 80        81        1600 Reeves Street  Cedar Hills        Reuter
#
#     Asking_Price  Selling_Price Listing_Date  Sale_Date
# 0         725000         645250     4/1/2018  6/16/2018
# ...

# %%
number = random.randint(0,10000)
print("Zach Drury , dr21637 ", number )
print('------------------------------')

# Problem 4. (8 points)
# List all realestates in the city of Cedar Hills and Selling price is over $300,000

names = df[(df['City'] == 'Cedar Hills') & (df['Selling_Price']>300000)] 
names
# Out:
# Zach Drury , dr21637  1882
# ------------------------------
#     Trans_No                 Address         City Selling_Agent  Asking_Price  \
# 0          1       8687 Kenwood Road  Cedar Hills     Hernandez        725000
# 33        34    11971 SW 269 Terrace  Cedar Hills         Carey        410000
# 34        35         1857 Pine Drive  Cedar Hills     Hernandez        560700
# 36        37  16235 Orange Boulevard  Cedar Hills          Lugo        395000
# 45        46   10700 Lake Shore Lane  Cedar Hills         Carey        650000
# 55        56     1629 NW 43rd Street  Cedar Hills         Carey        475000
# 72        73         10 Vestal Drive  Cedar Hills         Carey        555000
#
#     Selling_Price Listing_Date  Sale_Date
# 0          645250     4/1/2018  6/16/2018
# 33         397700     5/1/2018  6/26/2018
# 34         550000     5/1/2018  5/30/2018
# 36         380000     5/5/2018  7/16/2018
# 45         598000    5/15/2018   6/9/2018
# ...

# %%
number = random.randint(0,10000)
print("Zach Drury , dr21637 ", number )
print('------------------------------')


# Problem 5. ( 4+4 =8 points)   
# Display all selling agent names and display one agent for each line
print('Selling Agent names')
names = df['Selling_Agent'].unique()
print(names)
print()
print('Display each agents in a line')
print('--------------------------')
for name in names:
    print(name)
# Out:
# Zach Drury , dr21637  6489
# ------------------------------
# Selling Agent names
# ['Hernandez' 'Carey' 'Goodrich' 'Lugo' 'Minkus' 'Merkin' 'Pijuan' 'Reuter'
#  'Bethune' 'Hen']
#
# Display each agents in a line
# --------------------------
# Hernandez
# Carey
# Goodrich
# Lugo
# Minkus
# Merkin
# Pijuan
# Reuter
# Bethune
# Hen

# %%
number = random.randint(0,10000)
print("Zach Drury , dr21637 ", number )
print('------------------------------')


# Problem 6. (14 points)
# A) Show the total number of realestate listed in the dataset    
# B) Display the highestselling price of realestate  
# C) Display the average selling price, and average asking prince
# D) Compute the percentage of average selling price to asking price 


tot_real = df['Trans_No'].count()
high_sp = df['Selling_Price'].max()
avg_ap = df['Asking_Price'].mean()
avg_sp = df['Selling_Price'].mean()
percentage = (avg_sp/avg_ap)


print('\nThe total number of realestate:',format(tot_real, '.1f'))
print('\nThe highest selling price: $',format(high_sp, '.1f'))
print('\nAverage Asking Price:  $',format(avg_ap, '.1f'))
print('\nAverage Selling Price: $',format(avg_sp, '.1f'))
print('\nThe Percentage of Average Selling price to Average Asking price:',format(percentage, '.2%'))
# Out:
# Zach Drury , dr21637  5879
# ------------------------------
#
# The total number of realestate: 81.0
#
# The highest selling price: $ 1225000.0
#
# Average Asking Price:  $ 390110.5
#
# Average Selling Price: $ 354040.9
#
# The Percentage of Average Selling price to Average Asking price: 90.75%

# %% [markdown]
# # Part B:  (50 points)

# %%
number = random.randint(0,10000)
print("Zach Drury , dr21637 ", number )
print('------------------------------')


# Problem 1. ( 8 pts)
# Sorting the realestate data by city and selling price in descending order.

names.sort_values(['City','Selling_Price'], ascending = [False,False])
# Out:
# Zach Drury , dr21637  4336
# ------------------------------
#     Trans_No                Address    City Selling_Agent  Asking_Price  \
# 43        44   1414 N Sheridan Road  Alpine        Pijuan       1250000
# 11        12      575 South Choctaw  Alpine      Goodrich        750250
# 68        69      8923 Harris Drive  Alpine        Minkus        589000
# 5          6       7 Kingston Court  Alpine         Carey        500000
# 74        75       876 West Holiday  Alpine      Goodrich        475000
# ..       ...                    ...     ...           ...           ...
# 49        50    605 Reservoir Drive  Alpine        Reuter        310000
# 8          9     1370 Pinellas Road  Alpine          Lugo        219000
# 64        65    520 E Spring Street  Alpine        Minkus        189900
# 47        48  81 Island Drive South  Alpine       Bethune        147800
# 39        40    401 Pinecone Circle  Alpine      Goodrich       1500120
#
#     Selling_Price Listing_Date  Sale_Date
# ...

# %%
number = random.randint(0,10000)
print("Zach Drury , dr21637 ", number )
print('------------------------------')



# Problem 2. ( 8 pts)
# List top three highest selling price real estate sold in City Alpine
names = df[df['City'] == 'Alpine']
names.sort_values(by =['Selling_Price']).head(3)
# Out:
# Zach Drury , dr21637  4477
# ------------------------------
#     Trans_No                Address    City Selling_Agent  Asking_Price  \
# 39        40    401 Pinecone Circle  Alpine      Goodrich       1500120
# 47        48  81 Island Drive South  Alpine       Bethune        147800
# 64        65    520 E Spring Street  Alpine        Minkus        189900
#
#     Selling_Price Listing_Date  Sale_Date
# 39         140000     5/5/2018  9/30/2018
# 47         150000    5/22/2018  6/16/2018
# 64         186102     6/6/2018  7/26/2018

# %%
number = random.randint(0,10000)
print("Zach Drury , dr21637 ", number )
print('------------------------------')

#  Problem 3. ( 10 pts)
#  Show the average selling price of real estate sold in city Apine
#  Is its average selling price above or below the average selling price of all realstates?
#  res[(res.City=='Alpine') ]. 2 pt, 
#  SellingPrice.mean() 2 pts 
#  Compare SellingPrice.mean() 6 pts 

names = df[df['City'] == 'Alpine']

num1 = names['Selling_Price'].mean()
print('Average Selling Price in Alpine',format(num1, '.2f'))

num2 = df['Selling_Price'].mean()
print('Average selling price in all cities:', format(num2,'.2f'))
print()      
if num1 > num2:
    print("Is above the average selling price of all cities.")
else:
    print("Is below the average selling price of all cities.")
# Out:
# Zach Drury , dr21637  1352
# ------------------------------
# Average Selling Price in Alpine 414910.79
# Average selling price in all cities: 354040.86
#
# Is above the average selling price of all cities.

# %%
number = random.randint(0,10000)
print("Zach Drury , dr21637 ", number )
print('------------------------------')

# Problem 4. ( 14 pts)
# Display and plot the average Selling Price in each city in descending order. 

names = df[df['Selling_Price'].mean().sort_values(ascending = True)
names
names = num1[['City','Selling_Price']]


print('City                               Average Selling Price')
print('--------------------------------------------')

avg_spp = num1['Selling_Price']
for i in num1.index:
    print(res['Selling_Price'][i], '\t', format(res['City'][i], '.0f'))
# Out:
#   File "<ipython-input-108-c0074e1c0fa4>", line 9
#     names
#     ^
# SyntaxError: invalid syntax

# %%
number = random.randint(0,10000)
print("Zach Drury , dr21637 ", number )
print('------------------------------')

# Problem 5. ( 10 pt)
# Show the real estate number of each city,
# and sorted by the city name
# And plot the result as bar chart




names = df.groupby(df.City).Trans_No.sum().sort_values(ascending = False)

names = df.index
for name in names:
    print('{0: <20}'.format(name), '\t', format(names[name], '.0f'))

plt.title('Number of Real Estate Sold in Each City')
plt.xlabel('City')
plt.xlabel('Sale_Date')

plt.bar(res['City'],res['new_cases'], color='b')
# Out:
# Alpine            14
# American Fork     20
# Cedar Hills       12
# Eagle Mountain    24
# Lehi              11
# Name: City, dtype: int64

# %%
# Out:
#   File "<ipython-input-95-b43989ea0c9c>", line 2
# ...
#     ^
# SyntaxError: invalid syntax
